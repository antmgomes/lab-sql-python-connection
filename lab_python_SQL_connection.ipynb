# %%
# !pip install sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in c:\users\nocto\anaconda3\lib\site-packages (2.0.39)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\nocto\anaconda3\lib\site-packages (from sqlalchemy) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\nocto\anaconda3\lib\site-packages (from sqlalchemy) (4.12.2)

# %%
# !pip install pymysql

# %%
pip show sqlalchemy | grep Version
# Out:
# Note: you may need to restart the kernel to use updated packages.
# 'grep' is not recognized as an internal or external command,
# operable program or batch file.

# %%
pip show sqlalchemy | grep Version
# Out:
# Note: you may need to restart the kernel to use updated packages.
# 'grep' is not recognized as an internal or external command,
# operable program or batch file.

# %%
pip install --upgrade sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in c:\users\nocto\anaconda3\lib\site-packages (2.0.39)
# Collecting sqlalchemy
#   Downloading sqlalchemy-2.0.44-cp313-cp313-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: greenlet>=1 in c:\users\nocto\anaconda3\lib\site-packages (from sqlalchemy) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\nocto\anaconda3\lib\site-packages (from sqlalchemy) (4.12.2)
# Downloading sqlalchemy-2.0.44-cp313-cp313-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    -------------- ------------------------- 0.8/2.1 MB 4.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.8/2.1 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 4.3 MB/s eta 0:00:00
# Installing collected packages: sqlalchemy
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 2.0.39
#     Uninstalling SQLAlchemy-2.0.39:
#       Successfully uninstalled SQLAlchemy-2.0.39
# Successfully installed sqlalchemy-2.0.44
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install --upgrade sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in c:\users\nocto\anaconda3\lib\site-packages (2.0.44)
# Requirement already satisfied: greenlet>=1 in c:\users\nocto\anaconda3\lib\site-packages (from sqlalchemy) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\nocto\anaconda3\lib\site-packages (from sqlalchemy) (4.12.2)

# %%
import pandas as pd
import numpy as np
import pymysql
from sqlalchemy import create_engine
import getpass  # To get the password without showing the input
password = getpass.getpass()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import pymysql
#       4 from sqlalchemy import create_engine
#       5 import getpass  # To get the password without showing the input
#
# ModuleNotFoundError: No module named 'pymysql'
